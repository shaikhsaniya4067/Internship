# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\rutuj\Downloads\DSDBA\dataset_Facebook.csv",sep=';')

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
# ...

# %%
df.dtypes
# Out:
# Page total likes                                                         int64
# Type                                                                    object
# Category                                                                 int64
# Post Month                                                               int64
# Post Weekday                                                             int64
# Post Hour                                                                int64
# Paid                                                                   float64
# Lifetime Post Total Reach                                                int64
# Lifetime Post Total Impressions                                          int64
# Lifetime Engaged Users                                                   int64
# Lifetime Post Consumers                                                  int64
# Lifetime Post Consumptions                                               int64
# ...

# %%
df.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
#Creating data subset

subset1 = df[['Type','Category','like']]
subset1
# Out:
#        Type  Category    like
# 0     Photo         2    79.0
# 1    Status         2   130.0
# 2     Photo         3    66.0
# 3     Photo         2  1572.0
# 4     Photo         2   325.0
# ..      ...       ...     ...
# 495   Photo         3    53.0
# 496   Photo         2    53.0
# 497   Photo         1    93.0
# 498   Photo         3    91.0
# 499   Photo         2    91.0
#
# [500 rows x 3 columns]

# %%
subset2 = df.iloc[0:50]
subset2
# Out:
#     Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0             139441   Photo         2          12             4          3
# 1             139441  Status         2          12             3         10
# 2             139441   Photo         3          12             3          3
# 3             139441   Photo         2          12             2         10
# 4             139441   Photo         2          12             2          3
# 5             139441  Status         2          12             1          9
# 6             139441   Photo         3          12             1          3
# 7             139441   Photo         3          12             7          9
# 8             139441  Status         2          12             7          3
# 9             139441   Photo         3          12             6         10
# 10            139441  Status         2          12             5         10
# ...

# %%
subset3 = df[df['like']>500]
print(subset3[['Type','like']])
# Out:
#        Type    like
# 3     Photo  1572.0
# 14    Photo   577.0
# 17    Photo   678.0
# 28    Photo   523.0
# 67    Photo   697.0
# 101   Photo  1505.0
# 105   Photo   955.0
# 142  Status   859.0
# 168   Photo  1622.0
# 176   Photo  1047.0
# 191   Photo   766.0
# 199   Photo  1155.0
# 206   Photo   859.0
# 240   Photo   535.0
# 244   Photo  5172.0
# 254   Photo   755.0
# 264   Photo   529.0
# 270   Photo   696.0
# 272   Photo   534.0
# 323   Photo  1372.0
# 328   Photo   617.0
# 346   Photo   821.0
# 349   Photo  1639.0
# 379   Photo  1998.0
# 391   Photo   766.0
# 442   Photo   664.0
# 460   Photo  1546.0
# 476   Photo   579.0

# %%
subset4 = df[df['Paid']==1]
print(subset4[['Type','Paid']])
# Out:
#       Type  Paid
# 3    Photo   1.0
# 6    Photo   1.0
# 7    Photo   1.0
# 14   Photo   1.0
# 17   Photo   1.0
# ..     ...   ...
# 473  Photo   1.0
# 475  Photo   1.0
# 476  Photo   1.0
# 481   Link   1.0
# 491  Photo   1.0
#
# [139 rows x 2 columns]

# %%
subset5 = df[df['Type']=='Photo']
print(subset5[['Type', 'like', 'comment']])
# Out:
#       Type    like  comment
# 0    Photo    79.0        4
# 2    Photo    66.0        0
# 3    Photo  1572.0       58
# 4    Photo   325.0       19
# 6    Photo   249.0        3
# ..     ...     ...      ...
# 495  Photo    53.0        5
# 496  Photo    53.0        0
# 497  Photo    93.0        4
# 498  Photo    91.0        7
# 499  Photo    91.0        0
#
# [426 rows x 3 columns]

# %%
#merge data
merged_columns = pd.merge(subset1, subset3, on='Type', how='inner')
merged_columns
# Out:
#         Type  Category_x  like_x  Page total likes  Category_y  Post Month  \
# 0      Photo           2    79.0            139441           2          12
# 1      Photo           2    79.0            138414           2          12
# 2      Photo           2    79.0            138414           1          12
# 3      Photo           2    79.0            138895           2          12
# 4      Photo           2    79.0            138185           1          11
# ...      ...         ...     ...               ...         ...         ...
# 11542  Photo           2    91.0            111620           3           4
# 11543  Photo           2    91.0            109670           2           4
# 11544  Photo           2    91.0             98195           3           3
# 11545  Photo           2    91.0             92507           3           2
# 11546  Photo           2    91.0             86909           1           1
#
# ...

# %%
subset1 = subset1.reset_index(drop=True)
subset3 = subset3.reset_index(drop=True)

merged_rows = pd.concat([subset1, subset3], axis=0, ignore_index=True)

# %%
#sort data

Sorted_subset3 = subset3.sort_values(by='like',ascending=False)
print(Sorted_subset3[['Type','like']])
# Out:
#       Type    like
# 14   Photo  5172.0
# 23   Photo  1998.0
# 22   Photo  1639.0
# 8    Photo  1622.0
# 0    Photo  1572.0
# 26   Photo  1546.0
# 5    Photo  1505.0
# 19   Photo  1372.0
# 11   Photo  1155.0
# 9    Photo  1047.0
# 6    Photo   955.0
# 7   Status   859.0
# 12   Photo   859.0
# 21   Photo   821.0
# 10   Photo   766.0
# 24   Photo   766.0
# 15   Photo   755.0
# 4    Photo   697.0
# 17   Photo   696.0
# 2    Photo   678.0
# 25   Photo   664.0
# 20   Photo   617.0
# 27   Photo   579.0
# 1    Photo   577.0
# 13   Photo   535.0
# 18   Photo   534.0
# 16   Photo   529.0
# 3    Photo   523.0

# %%
#transpose data

trans = subset4.T
trans
# Out:
#                                                        3       6       7    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo   Photo   Photo
# Category                                                 2       3       3
# Post Month                                              12      12      12
# Post Weekday                                             2       1       7
# Post Hour                                               10       3       9
# Paid                                                   1.0     1.0     1.0
# Lifetime Post Total Reach                            50128   11692   13720
# Lifetime Post Total Impressions                      87991   19479   24137
# Lifetime Engaged Users                                2211     481     537
# Lifetime Post Consumers                                790     265     232
# ...

# %%
#reshaping

data_array = df.values
total_elements = data_array.size
reshaped_data = data_array.reshape(100, int(total_elements/100))
print("Original Shape:", df.shape)
print("Reshaped Shape:", reshaped_data.shape)
# Out:
# Original Shape: (500, 19)
# Reshaped Shape: (100, 95)

# %%
#pivot table

pivot_table = pd.pivot_table(df, values='like',index='Type',aggfunc='mean')
pivot_table
# Out:
#               like
# Type
# Link     73.318182
# Photo   182.611765
# Status  176.711111
# Video   231.428571
